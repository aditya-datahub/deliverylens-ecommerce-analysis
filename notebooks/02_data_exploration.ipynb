# %%
import pandas as pd
import sqlite3

# Database connect karo
conn = sqlite3.connect('../data/deliverylens.db')

# Teeno tables dekho
orders = pd.read_sql("SELECT * FROM orders", conn)
items = pd.read_sql("SELECT * FROM items", conn)
reviews = pd.read_sql("SELECT * FROM reviews", conn)

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered           02-10-17 10:56    02-10-17 11:07
# 1    delivered           24-07-18 20:41    26-07-18 03:24
# 2    delivered           08-08-18 08:38    08-08-18 08:55
# 3    delivered           18-11-17 19:28    18-11-17 19:45
# 4    delivered           13-02-18 21:18    13-02-18 22:20
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0               04-10-17 19:55                10-10-17 21:25
# 1               26-07-18 14:31                07-08-18 15:27
# 2               08-08-18 13:50                17-08-18 18:06
# 3               22-11-17 13:39                02-12-17 00:28
# 4               14-02-18 19:46                16-02-18 18:17
#
#   order_estimated_delivery_date
# 0                18-10-17 00:00
# 1                13-08-18 00:00
# 2                04-09-18 00:00
# 3                15-12-17 00:00
# 4                26-02-18 00:00

# %%
items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %%
reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                 None
# 1             5                 None
# 2             5                 None
# 3             5                 None
# 4             5                 None
#
#                               review_comment_message review_creation_date  \
# 0                                               None       18-01-18 00:00
# 1                                               None       10-03-18 00:00
# 2                                               None       17-02-18 00:00
# 3              Recebi bem antes do prazo estipulado.       21-04-17 00:00
# 4  Parabéns lojas lannister adorei comprar pela I...       01-03-18 00:00
#
#   review_answer_timestamp
# 0          18-01-18 21:46
# 1          11-03-18 03:05
# 2          18-02-18 14:36
# 3          21-04-17 22:02
# 4          02-03-18 10:26

# %%
print("Orders shape:", orders.shape)
print("Items shape:", items.shape)
print("Reviews shape:", reviews.shape)
# Out:
# Orders shape: (99441, 8)
# Items shape: (112650, 7)
# Reviews shape: (99224, 7)

# %%
print("Orders columns:", orders.columns.tolist())
print("Items columns:", items.columns.tolist()) 
print("Reviews columns:", reviews.columns.tolist())
# Out:
# Orders columns: ['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date']
# Items columns: ['order_id', 'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date', 'price', 'freight_value']
# Reviews columns: ['review_id', 'order_id', 'review_score', 'review_comment_title', 'review_comment_message', 'review_creation_date', 'review_answer_timestamp']

# %%
print("=== Orders Nulls ===")
print(orders.isnull().sum())

print("\n=== Items Nulls ===")
print(items.isnull().sum())

print("\n=== Reviews Nulls ===")
print(reviews.isnull().sum())
# Out:
# === Orders Nulls ===
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64
#
# === Items Nulls ===
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
#
# === Reviews Nulls ===
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
print("=== Orders dtypes ===")
print(orders.dtypes)

print("\n=== Items dtypes ===")
print(items.dtypes)

print("\n=== Reviews dtypes ===")
print(reviews.dtypes)
# Out:
# === Orders dtypes ===
# order_id                         object
# customer_id                      object
# order_status                     object
# order_purchase_timestamp         object
# order_approved_at                object
# order_delivered_carrier_date     object
# order_delivered_customer_date    object
# order_estimated_delivery_date    object
# dtype: object
#
# === Items dtypes ===
# order_id                object
# order_item_id            int64
# product_id              object
# seller_id               object
# shipping_limit_date     object
# price                  float64
# freight_value          float64
# dtype: object
#
# === Reviews dtypes ===
# review_id                  object
# order_id                   object
# review_score                int64
# review_comment_title       object
# review_comment_message     object
# review_creation_date       object
# review_answer_timestamp    object
# dtype: object
