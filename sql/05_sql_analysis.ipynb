# %%
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus

password = quote_plus("AdityaSharma@18")
engine = create_engine(f'mysql+pymysql://root:{password}@localhost/deliverylens')

# CSVs load karo
orders = pd.read_csv('../data/olist_orders_dataset.csv')
items = pd.read_csv('../data/olist_order_items_dataset.csv')
reviews = pd.read_csv('../data/olist_order_reviews_dataset.csv')

# MySQL mein push karo
orders.to_sql('orders', engine, if_exists='replace', index=False)
items.to_sql('items', engine, if_exists='replace', index=False)
reviews.to_sql('reviews', engine, if_exists='replace', index=False)

print("Done!")
# Out:
# Done!
